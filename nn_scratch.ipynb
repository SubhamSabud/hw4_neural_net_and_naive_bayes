# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms

import matplotlib.pyplot as plt

# Define the hyperparameters
d = 784 # input dimension
d1 = 300 # hidden dimension
k = 10 # output dimension
lr = 0.01 # learning rate
batch_size = 16 # batch size
epochs = 40 # number of epochs

# MNIST dataset
train_dataset = torchvision.datasets.MNIST(root='data', 
                                           train=True, 
                                           transform=transforms.ToTensor(),  
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='data', 
                                          train=False, 
                                          transform=transforms.ToTensor())

# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False)
# Define the activation functions and the loss function
# Define the sigmoid function
def sigmoid(z):
    return 1 / (1 + torch.exp(-z))

# Define the softmax function
def softmax(z):
    exp_z = torch.exp(z)
    return exp_z / torch.sum(exp_z, dim=1, keepdim=True)

# Define the cross-entropy loss function
def cross_entropy(y_pred, y_true):
    return -torch.sum(y_true * torch.log(y_pred), dim=1).mean()


# Define the model parameters and initialize them randomly
W1 = torch.randn(d1, d, requires_grad=True)
W2 = torch.randn(k, d1, requires_grad=True)



# Define lists to store the training and testing accuracy and loss
train_acc_list = []
train_loss_list = []
test_acc_list = []
test_loss_list = []

# Train the model using SGD without momentum
for epoch in range(epochs):
    # Initialize the training accuracy and loss for each epoch
    train_acc = 0
    train_loss = 0

    # Loop over the training batches
    for x, y in train_loader:
        # Flatten the input images
        x = x.view(-1, d)

        # Convert the labels into one-hot vectors
        y_onehot = torch.zeros(batch_size, k)
        y_onehot.scatter_(1, y.view(-1, 1), 1)

        # Forward pass: compute the predicted outputs
        z1 = torch.matmul(x, W1.t())
        a1 = sigmoid(z1)
        z2 = torch.matmul(a1, W2.t())
        y_pred = softmax(z2)

        # Compute the loss
        loss = cross_entropy(y_pred, y_onehot)

        # Backward pass: compute the gradients
        loss.backward()

        # Update the parameters using SGD
        with torch.no_grad():
            W1 -= lr * W1.grad
            W2 -= lr * W2.grad

            # Zero the gradients for the next iteration
            W1.grad.zero_()
            W2.grad.zero_()

        # Compute the accuracy
        y_pred_labels = torch.argmax(y_pred, dim=1)
        acc = torch.sum(y_pred_labels == y).item() / batch_size

        # Accumulate the accuracy and loss over the epoch
        train_acc += acc
        train_loss += loss.item()

    # Compute the average accuracy and loss over the epoch
    train_acc /= len(train_loader)
    train_loss /= len(train_loader)

    # Append the accuracy and loss to the lists
    train_acc_list.append(train_acc)
    train_loss_list.append(train_loss)

    # Print the epoch summary
    print(f'Epoch {epoch+1}, Train Accuracy: {train_acc:.4f}, Train Loss: {train_loss:.4f}')

    # Initialize the testing accuracy and loss for each epoch
    test_acc = 0
    test_loss = 0

    # Loop over the testing batches
    for x, y in test_loader:
        # Flatten the input images
        x = x.view(-1, d)

        # Convert the labels into one-hot vectors
        y_onehot = torch.zeros(batch_size, k)
        y_onehot.scatter_(1, y.view(-1, 1), 1)

        # Forward pass: compute the predicted outputs
        z1 = torch.matmul(x, W1.t())
        a1 = sigmoid(z1)
        z2 = torch.matmul(a1, W2.t())
        y_pred = softmax(z2)

        # Compute the loss
        loss = cross_entropy(y_pred, y_onehot)

        # Compute the accuracy
        y_pred_labels = torch.argmax(y_pred, dim=1)
        acc = torch.sum(y_pred_labels == y).item() / batch_size

        # Accumulate the accuracy and loss over the epoch
        test_acc += acc
        test_loss += loss.item()

    # Compute the average accuracy and loss over the epoch
    test_acc /= len(test_loader)
    test_loss /= len(test_loader)

    # Append the accuracy and loss to the lists
    test_acc_list.append(test_acc)
    test_loss_list.append(test_loss)

    # Print the epoch summary
    print(f'Epoch {epoch+1}, Test Accuracy: {test_acc:.4f}, Test Loss: {test_loss:.4f}')

# Plot the training and testing accuracy curve
plt.figure()
plt.plot(train_acc_list, label='Train')
plt.plot(test_acc_list, label='Test')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Testing Accuracy Curve')
plt.legend()
plt.savefig("accuracy_curve_Q42.jpg")
plt.show()

# Plot the training and testing loss curve
plt.figure()
plt.plot(train_loss_list, label='Train')
plt.plot(test_loss_list, label='Test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Testing Loss Curve')
plt.legend()
plt.savefig("loss_curve_Q42.jpg")
plt.show()
# Out:
# Epoch 1, Train Accuracy: 0.5940, Train Loss: 2.6261
# Epoch 1, Test Accuracy: 0.7529, Test Loss: 1.2985
# Epoch 2, Train Accuracy: 0.7841, Train Loss: 1.1148
# Epoch 2, Test Accuracy: 0.8122, Test Loss: 0.9389
# Epoch 3, Train Accuracy: 0.8271, Train Loss: 0.8629
# Epoch 3, Test Accuracy: 0.8387, Test Loss: 0.7888
# Epoch 4, Train Accuracy: 0.8499, Train Loss: 0.7313
# Epoch 4, Test Accuracy: 0.8536, Test Loss: 0.6959
# Epoch 5, Train Accuracy: 0.8633, Train Loss: 0.6452
# Epoch 5, Test Accuracy: 0.8642, Test Loss: 0.6351
# Epoch 6, Train Accuracy: 0.8740, Train Loss: 0.5828
# Epoch 6, Test Accuracy: 0.8726, Test Loss: 0.5948
# Epoch 7, Train Accuracy: 0.8819, Train Loss: 0.5339
# Epoch 7, Test Accuracy: 0.8789, Test Loss: 0.5553
# Epoch 8, Train Accuracy: 0.8884, Train Loss: 0.4945
# Epoch 8, Test Accuracy: 0.8839, Test Loss: 0.5290
# Epoch 9, Train Accuracy: 0.8939, Train Loss: 0.4619
# Epoch 9, Test Accuracy: 0.8887, Test Loss: 0.5039
# Epoch 10, Train Accuracy: 0.8993, Train Loss: 0.4342
# Epoch 10, Test Accuracy: 0.8915, Test Loss: 0.4848
# Epoch 11, Train Accuracy: 0.9029, Train Loss: 0.4112
# Epoch 11, Test Accuracy: 0.8952, Test Loss: 0.4676
# Epoch 12, Train Accuracy: 0.9065, Train Loss: 0.3908
# Epoch 12, Test Accuracy: 0.8989, Test Loss: 0.4510
# Epoch 13, Train Accuracy: 0.9094, Train Loss: 0.3720
# Epoch 13, Test Accuracy: 0.8988, Test Loss: 0.4375
# Epoch 14, Train Accuracy: 0.9129, Train Loss: 0.3560
# Epoch 14, Test Accuracy: 0.9027, Test Loss: 0.4261
# Epoch 15, Train Accuracy: 0.9150, Train Loss: 0.3411
# Epoch 15, Test Accuracy: 0.9040, Test Loss: 0.4177
# Epoch 16, Train Accuracy: 0.9179, Train Loss: 0.3281
# Epoch 16, Test Accuracy: 0.9060, Test Loss: 0.4064
# Epoch 17, Train Accuracy: 0.9205, Train Loss: 0.3157
# Epoch 17, Test Accuracy: 0.9078, Test Loss: 0.3957
# Epoch 18, Train Accuracy: 0.9229, Train Loss: 0.3044
# Epoch 18, Test Accuracy: 0.9075, Test Loss: 0.3912
# Epoch 19, Train Accuracy: 0.9247, Train Loss: 0.2940
# Epoch 19, Test Accuracy: 0.9102, Test Loss: 0.3800
# Epoch 20, Train Accuracy: 0.9267, Train Loss: 0.2847
# Epoch 20, Test Accuracy: 0.9105, Test Loss: 0.3752
# Epoch 21, Train Accuracy: 0.9291, Train Loss: 0.2756
# Epoch 21, Test Accuracy: 0.9124, Test Loss: 0.3675
# Epoch 22, Train Accuracy: 0.9309, Train Loss: 0.2676
# Epoch 22, Test Accuracy: 0.9132, Test Loss: 0.3614
# Epoch 23, Train Accuracy: 0.9322, Train Loss: 0.2597
# Epoch 23, Test Accuracy: 0.9137, Test Loss: 0.3554
# Epoch 24, Train Accuracy: 0.9338, Train Loss: 0.2522
# Epoch 24, Test Accuracy: 0.9145, Test Loss: 0.3551
# Epoch 25, Train Accuracy: 0.9351, Train Loss: 0.2455
# Epoch 25, Test Accuracy: 0.9153, Test Loss: 0.3466
# Epoch 26, Train Accuracy: 0.9364, Train Loss: 0.2390
# Epoch 26, Test Accuracy: 0.9173, Test Loss: 0.3409
# Epoch 27, Train Accuracy: 0.9375, Train Loss: 0.2330
# Epoch 27, Test Accuracy: 0.9173, Test Loss: 0.3356
# Epoch 28, Train Accuracy: 0.9395, Train Loss: 0.2271
# Epoch 28, Test Accuracy: 0.9177, Test Loss: 0.3324
# Epoch 29, Train Accuracy: 0.9408, Train Loss: 0.2217
# Epoch 29, Test Accuracy: 0.9190, Test Loss: 0.3280
# Epoch 30, Train Accuracy: 0.9417, Train Loss: 0.2162
# Epoch 30, Test Accuracy: 0.9187, Test Loss: 0.3240
# Epoch 31, Train Accuracy: 0.9430, Train Loss: 0.2116
# Epoch 31, Test Accuracy: 0.9196, Test Loss: 0.3227
# Epoch 32, Train Accuracy: 0.9443, Train Loss: 0.2068
# Epoch 32, Test Accuracy: 0.9208, Test Loss: 0.3184
# Epoch 33, Train Accuracy: 0.9450, Train Loss: 0.2022
# Epoch 33, Test Accuracy: 0.9224, Test Loss: 0.3120
# Epoch 34, Train Accuracy: 0.9459, Train Loss: 0.1978
# Epoch 34, Test Accuracy: 0.9216, Test Loss: 0.3091
# Epoch 35, Train Accuracy: 0.9470, Train Loss: 0.1939
# Epoch 35, Test Accuracy: 0.9226, Test Loss: 0.3071
# Epoch 36, Train Accuracy: 0.9482, Train Loss: 0.1897
# Epoch 36, Test Accuracy: 0.9233, Test Loss: 0.3051
# Epoch 37, Train Accuracy: 0.9493, Train Loss: 0.1859
# Epoch 37, Test Accuracy: 0.9245, Test Loss: 0.3007
# Epoch 38, Train Accuracy: 0.9501, Train Loss: 0.1823
# Epoch 38, Test Accuracy: 0.9239, Test Loss: 0.2994
# Epoch 39, Train Accuracy: 0.9504, Train Loss: 0.1788
# Epoch 39, Test Accuracy: 0.9249, Test Loss: 0.2955
# Epoch 40, Train Accuracy: 0.9516, Train Loss: 0.1756
# Epoch 40, Test Accuracy: 0.9254, Test Loss: 0.2934
